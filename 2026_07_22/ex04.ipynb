# %% [markdown]
# ### 다음 순서대로 데이터 전처리를 진행한 1~7의 출력결과를 보고, 빈 곳을 채우시오.
# - 'dt' 컬럼의 데이터 타입을 datetime으로 변경하세요.
# - 'City'와 'Country'컬럼의 결측값을 해당 컬럼의 최빈값으로 대체하세요.
# - 'Average TemPerature'컬럼의 결측값을 해당 컬럼의 평균값으로 대체하세요.
# - 'Average Temperature'컬럼에서 boxplot을 이용하여 이상치를 제거하세요.
# - 'dt'컬럼에서 년도, 월, 일자 데이터를 추출하여 'Year', 'Month', 'Day'컬럼을 추가하세요.
#   (dt.year, dt.month, dt.day를 이용할 것|)

# %%
import pandas as pd

# %%
# 데이터 셋 불러오기
df = pd.read_csv('연습문제10-4.csv')
print(df.head())
# Out:
#            dt  AverageTemperature     City Latitude Longitude
# 0  1849-01-01              26.704  Abidjan    5.63N     3.23W
# 1  1849-02-01              27.434  Abidjan    5.63N     3.23W
# 2  1849-03-01              28.101  Abidjan    5.63N     3.23W
# 3  1849-04-01              26.140  Abidjan    5.63N     3.23W
# 4  1849-05-01              25.427  Abidjan    5.63N     3.23W

# %%
# 'df' 컬럼의 데이터 타입 변경
df= df.apply(pd.to_numeric) 
print(df.info())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/lib.pyx:2478, in pandas._libs.lib.maybe_convert_numeric()
# -> 2478 'Could not get source, probably due dynamically evaluated source code.'
#
# ValueError: Unable to parse string "1849-01-01"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 # 'df' 컬럼의 데이터 타입 변경
# ----> 2 df= df.apply(pd.to_numeric)
#       3 print(df.info())
#
# File c:\Users\Administrator\bigdata2026\data_analysis\.venv\Lib\site-packages\pandas\core\frame.py:12435, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   12421         raise ValueError(f"Unknown engine '{engine}'")
#   12423     op = frame_apply(
#   12424         self,
#   12425         func=func,
# ...
