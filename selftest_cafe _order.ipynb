# %%
cafe_menu = [
    {"name": "아메리카노", "price": 4000, "category": "커피"},
    {"name": "에스프레소", "price": 3500, "category": "커피"},
    {"name": "카푸치노", "price": 4000, "category": "커피"},
    {"name": "푸라푸치노", "price": 4000, "category": "커피"},
    {"name": "카라멜마키아토", "price": 5000, "category": "커피"},
    {"name": "화이트모카", "price": 4500, "category": "커피"},
    {"name": "바닐라라떼", "price": 5000, "category": "커피"},
    {"name": "카페라떼", "price": 4500, "category": "커피"},
    {"name": "피넛라떼", "price": 5000, "category": "커피"},
    {"name": "토피넛라떼", "price": 4500, "category": "커피"},
    {"name": "녹차라떼", "price": 5200, "category": "커피"},
    {"name": "소이라떼", "price": 4500, "category": "커피"},
    {"name": "스무디", "price": 5200, "category": "커피"},
    {"name": "딸기스무디", "price": 5800, "category": "음료"},
    {"name": "망고스무디", "price": 5800, "category": "음료"},
    {"name": "망고에이드", "price": 5500, "category": "음료"},
    {"name": "핫초코", "price": 5500, "category": "음료"},
    {"name": "망고에이드", "price": 5500, "category": "음료"},
	{"name": "청포도에이드", "price": 5800, "category": "음료"},
    {"name": "자몽에이드", "price": 5500, "category": "음료"},
    {"name": "핫초코", "price": 5500, "category": "음료"},
	{"name": "치즈케이크", "price": 6000, "category": "디저트"},
    {"name": "초코케이크", "price": 6000, "category": "디저트"},
    {"name": "화이트쿠키", "price": 2500, "category": "디저트"},
    {"name": "초코쿠키", "price": 2500, "category": "디저트"},
    {"name": "피넛쿠키", "price": 2500, "category": "디저트"},
]

# %%
print("카페 메뉴 조회 시스템")
print("원하는 기능의 번호를 입력하세요")


choice = int(input(f'1.가격별 메뉴조회 2.종류별 메뉴조회 3.주문  0.종료 : '))
if choice == 1 :
    print("--- [가격별 조회] ---")
    min_price = int(input(f'최저가격을 입력하세요!'))
    max_price = int(input(f'최고가격을 입력하세요!'))
    for menu in cafe_menu:
            if min_price <= menu["price"] <= max_price:
                print(f"- {menu['name']} ({menu['price']}원) [{menu['category']}]")

elif choice == 2:
    menu_kind = int(input(f'종류별 메뉴 조회(1.커피 2.음료 3.디저트) :'))
    if menu_kind == 1:
        for menu in cafe_menu:    
            if "커피" == menu['category'] :
                print(f"- {menu['name']} ({menu['price']}원) [{menu['category']}]")
    elif menu_kind == 2:
        for menu in cafe_menu:    
            if "음료" == menu['category'] :
                print(f"- {menu['name']} ({menu['price']}원) [{menu['category']}]")
    else:
        if menu_kind == 3:
            for menu in cafe_menu:    
                if "디저트" == menu['category'] :
                 print(f"- {menu['name']} ({menu['price']}원) [{menu['category']}]")
elif choice == 3:
    menu_order = input(f'원하는 메뉴를 입력하세요: ')
    for menu in cafe_menu:    
        if menu['name'] == menu_order:
            print(f"- {menu['name']} ({menu['price']}원) [{menu['category']}]")
else:
    print('스마트 메뉴 조회 시스템을 종료합니다.')
# Out:
# 카페 메뉴 조회 시스템
# 원하는 기능의 번호를 입력하세요
# 스마트 메뉴 조회 시스템을 종료합니다.
